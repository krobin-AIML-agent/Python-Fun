# %% [markdown]
# ### **Key Advanced Topics**

# %% [markdown]
# ## **CRUD Ops**

# %%
# Initialize "users table"
users = []

# -------------------------------
# CREATE (equivalent of SQL INSERT)
# -------------------------------
def create_user(user_id, name):
    """Insert a new user into the table."""
    users.append({"id": user_id, "name": name})
    return f"User {name} added!"

# -------------------------------
# READ (equivalent of SQL SELECT)
# -------------------------------
def read_user(user_id):
    """Select a user by ID."""
    for user in users:
        if user["id"] == user_id:
            return user
    return "User not found."

# -------------------------------
# UPDATE (equivalent of SQL UPDATE)
# -------------------------------
def update_user(user_id, new_name):
    """Update a user's name by ID."""
    for user in users:
        if user["id"] == user_id:
            user["name"] = new_name
            return f"User {user_id} updated to {new_name}"
    return "User not found."

# -------------------------------
# DELETE (equivalent of SQL DELETE)
# -------------------------------
def delete_user(user_id):
    """Delete a user by ID."""
    global users
    users = [u for u in users if u["id"] != user_id]
    return f"User {user_id} deleted."

# -------------------------------
# EXAMPLE RUN
# -------------------------------
print(create_user(1, "Kev"))         # INSERT
print(create_user(2, "Jordan"))      # INSERT
print(read_user(1))                  # SELECT
print(update_user(2, "Mike"))        # UPDATE
print(delete_user(1))                # DELETE
print(users)                         # Show remaining table

# %% [markdown]
# ## **Command Line Interface (CLI) Program**

# %%
from argparse import ArgumentParser  # For parsing command line arguments
 
parser = ArgumentParser() # Create the parser

parser.add_argument('--output', '-o', required=True, help='The destination file for the output of this program') # Add the arguments to the parser
parser.add_argument('--text', '-t', required=True, help='The text to write to the file') # Add the arguments to the parser


args = parser.parse_args()  # Parse the command line arguments

with open(args.output, 'w') as f: # Open the output file for writing
    f.write(args.text+'\n') # Write the text to the file

print(f'Wrote "{args.text}" to file "{args.output}"')  # Print a message indicating success

## THINGS you would want to adjust:
# File Path - If you want flexibility, make the filename a CLI argument (--file users.json).
# Data Format - JSON is easiest, but you could also do CSV (though then you need csv module and fixed columns).
# Validation - With persistence, you may want to prevent duplicates or enforce unique IDs.
# Error Handling - If the file is empty or corrupted, handle gracefully (try/except).
# Out:
# usage: ipykernel_launcher.py [-h] --output OUTPUT --text TEXT
# ipykernel_launcher.py: error: the following arguments are required: --output/-o, --text/-t
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\kevin\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# **Example**

# %% [markdown]
# **1. Navigation & Files****

# %% [markdown]
# **# CLI commands**
#
# ls       # list files
#
# cd ..    # change directory
#
# pwd      # show current path
#
# mkdir test_folder   # make directory
#
# rm -r test_folder   # remove directory

# %% [markdown]
# **2. Chaining**

# %%
cat file.txt | grep "error" > errors.txt

# %% [markdown]
# **3. Process Control**

# %%
ps aux       # show processes
kill -9 PID  # kill process

# %% [markdown]
# **4. Scripting with Python + argparse**

# %%
# save as cli_demo.py
import argparse

parser = argparse.ArgumentParser()
parser.add_argument("--name", "-n", required=True)
args = parser.parse_args()

print(f"Hello {args.name}, CLI works!")

# %% [markdown]
# **Then run file in terminal**

# %%
python cli_demo.py -n Kevin

# %% [markdown]
# **How They Work Together (ETL Pipeline)**

# %%
"""
ETL Demo:
1. Fetch data from API (Extract).
2. Transform with pandas.
3. Save to CSV (Load).
4. Automate with cron/Task Scheduler.
"""
import requests
import pandas as pd

# Extract
url = "https://jsonplaceholder.typicode.com/users"
data = requests.get(url).json()

# Transform
df = pd.DataFrame(data)[["id", "name", "email"]]

# Load
df.to_csv("users.csv", index=False)

print("Pipeline complete! Data saved to users.csv")

# %% [markdown]
# ## **Python & SQL Connection**

# %% [markdown]
# **Python & PostgresSQL connection using SQLAlchemy | STEP 1**

# %%
## First do: pip install sqlalchemy psycopg2   # psycopg2 for PostgreSQL, or another driver

from sqlalchemy import create_engine, text

## Created an Engine in Python
engine = create_engine("postgresql+psycopg2://postgres:password@localhost:0000/database_name") ## Database Engine Connector

## Opened a Connection & Sent SQL Commands
with engine.connect() as conn:
    result = conn.execute(text("SELECT version();"))
    print(result.fetchone())

##Proof of Concept Output: ('PostgreSQL 17.6 on x86_64-windows, compiled by msvc-19.44.35213, 64-bit',)

## Things that Change:
# Password
# Localhost
# Database name
# Out:
# ('PostgreSQL 17.6 on x86_64-windows, compiled by msvc-19.44.35213, 64-bit',)

# %% [markdown]
# **Creating Table in Python that will Reflect in PostegreSQL | STEP 2**

# %%
with engine.begin() as conn:
    conn.execute(text("CREATE SCHEMA IF NOT EXISTS portfolio;"))
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS portfolio.ai_learning_population (        
            id SERIAL PRIMARY KEY,
            score NUMERIC,
            stage VARCHAR(20)
        )
    """))

## Things that Changing
# Schema Design

# %% [markdown]
# ## **APIs & Hypertext Transfer Protocols (HTTP Methods)**

# %%
import requests

base_url = "https://jsonplaceholder.typicode.com/users"

# GET (Read)
resp = requests.get(f"{base_url}/1") 
print(resp.json())   # user with id=1

# POST (Create)
resp = requests.post(base_url, json={"name": "Kev"})
print(resp.json())

# PUT (Update - full)
resp = requests.put(f"{base_url}/1", json={"name": "Kevin Updated"})
print(resp.json())

# PATCH (Update - partial)
resp = requests.patch(f"{base_url}/1", json={"name": "Kev R"})
print(resp.json())

# DELETE
resp = requests.delete(f"{base_url}/1")
print(resp.status_code)  # 200 if success

# %% [markdown]
# **REST API**

# %%
# REST API Demo with JSONPlaceholder
import requests

url = "https://jsonplaceholder.typicode.com/users"

# GET (read) 
print("GET:", requests.get(url + "/1").json()) 

# POST (create)
print("POST:", requests.post(url, json={"name": "Kev"}).json()) 

# PUT (update full)
print("PUT:", requests.put(url + "/1", json={"name": "Kevin Updated"}).json())

# DELETE
print("DELETE:", requests.delete(url + "/1").status_code)

# %% [markdown]
# **SOAP API (Legacy & XML)**

# %%
from zeep import Client

wsdl = "http://www.dneonline.com/calculator.asmx?WSDL"
client = Client(wsdl)
print("SOAP Add:", client.service.Add(5, 7))

# --- Step 1: Import the SOAP client library (zeep) ---
# Zeep is a Python library that makes it easy to work with SOAP APIs
# SOAP (Simple Object Access Protocol) = XML-based web services (older than REST)
# --- Step 2: Point to the WSDL (Web Services Description Language) ---
# A WSDL file describes the SOAP service: available operations, inputs, outputs.
# Here we use a public demo service: "Calculator"
# --- Step 3: Create a SOAP client bound to the WSDL ---
# The Client object reads the WSDL and creates Python methods
# that map to the SOAP operations (e.g., Add, Subtract, Multiply, Divide).
# --- Step 4: Call a SOAP operation ---
# Now we can call the service like a Python method.
# Example: Add(5, 7) should return 12.

# --- Step 5: Print the result ---
# Out:
# SOAP Add: 12

# %% [markdown]
# **GraphQL API**

# %%
import requests

url = "https://countries.trevorblades.com/"
query = """
{
  country(code: "US") {
    name
    capital
    emoji
  }
}
"""
r = requests.post(url, json={"query": query})
print("GraphQL:", r.json())

# --- Step 1: Import requests library ---
# requests lets us send HTTP requests in Python (GET, POST, etc.)
# --- Step 2: Define the GraphQL endpoint ---
# This is a public GraphQL API that provides data about countries.
# --- Step 3: Write the GraphQL query ---
# GraphQL queries look like JSON, but they describe *what fields we want back*.
# Here: get the country with code "US" and return only name, capital, and emoji.
# --- Step 4: Send the query to the API ---
# GraphQL uses POST requests.
# The query must be sent as JSON with the key "query".
# --- Step 5: Print the response in JSON format ---
# The API will only return the fields we asked for.
# Out:
# GraphQL: {'data': {'country': {'capital': 'Washington D.C.', 'emoji': '🇺🇸', 'name': 'United States'}}}

# %% [markdown]
# **Authentication**

# %%
import requests

API_KEY = "your_api_key_here"
url = "https://api.openweathermap.org/data/2.5/weather"
params = {"q": "London", "appid": API_KEY}

r = requests.get(url, params=params)
print("Weather:", r.json())

# --- Step 1: Import requests library ---
# We'll use requests to send HTTP requests to the weather API.
# --- Step 2: Define API credentials and endpoint ---
# You need a valid API key from OpenWeatherMap (free signup).
# --- Step 3: Define parameters for the request ---
# "q" = city name
# "appid" = authentication with your API key
# --- Step 4: Send GET request with parameters ---
# requests.get() will build the full URL with ?q=London&appid=...
# --- Step 5: Print the response in JSON format ---
# The API responds with weather data in JSON format.
# Out:
# Weather: {'cod': 401, 'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}

# %% [markdown]
# ## **WEBSCRAPING**

# %% [markdown]
# **Web Scraping Example with BeautifulSoup #1**

# %%
import requests # type: ignore
from bs4 import BeautifulSoup

url = "http://books.toscrape.com/"
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

books = []

# Each book is inside <article class="product_pod">
for book in soup.find_all("article", class_="product_pod"):
    title = book.h3.a["title"]
    price = book.find("p", class_="price_color").get_text(strip=True)
    books.append({"title": title, "price": price})

# Show first 5
for b in books[:5]:
    print(b)

# --- Step 1: Import libraries ---
# requests: to send HTTP requests and fetch HTML
# BeautifulSoup: to parse and extract data from HTML
# --- Step 2: Define the target URL ---
# We're scraping a demo site made for practice: "Books to Scrape"
# --- Step 3: Add headers ---
# This makes the request look like it's coming from a browser (helps avoid blocks).
##headers = {
   ## "User-Agent": (
    ## "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
    ## "AppleWebKit/537.36 (KHTML, like Gecko) "
    ##  "Chrome/120.0.0.0 Safari/537.36"
   ## )
##}
# --- Step 4: Send GET request to fetch the page ---
# --- Step 5: Parse HTML with BeautifulSoup ---
# --- Step 6: Extract info ---
# Out:
# {'title': 'A Light in the Attic', 'price': 'Â£51.77'}
# {'title': 'Tipping the Velvet', 'price': 'Â£53.74'}
# {'title': 'Soumission', 'price': 'Â£50.10'}
# {'title': 'Sharp Objects', 'price': 'Â£47.82'}
# {'title': 'Sapiens: A Brief History of Humankind', 'price': 'Â£54.23'}

# %% [markdown]
# **Web Scraping Example with BeautifulSoup #2**

# %%
import requests
from bs4 import BeautifulSoup

url = "http://quotes.toscrape.com/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

quotes = []

for q in soup.find_all("div", class_="quote"):
    text = q.find("span", class_="text").get_text(strip=True)
    author = q.find("small", class_="author").get_text(strip=True)
    quotes.append({"quote": text, "author": author})

# Show first 5
for q in quotes[:5]:
    print(q)

# --- Step 1: Import libraries ---
# requests: send HTTP requests to fetch HTML
# BeautifulSoup: parse and extract information from HTML
# --- Step 2: Define target URL ---
# "Quotes to Scrape" is a sandbox site for practicing scraping
# --- Step 3: Fetch the page content ---
# --- Step 4: Parse HTML with BeautifulSoup ---
## soup = BeautifulSoup(response.text, "html.parser")
# --- Step 5: Extract quotes ---
## quotes = []
# Each quote is inside <div class="quote">
# --- Step 6: Show sample results ---
# Print the first 5 scraped quotes
# Out:
# {'quote': '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”', 'author': 'Albert Einstein'}
# {'quote': '“It is our choices, Harry, that show what we truly are, far more than our abilities.”', 'author': 'J.K. Rowling'}
# {'quote': '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”', 'author': 'Albert Einstein'}
# {'quote': '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”', 'author': 'Jane Austen'}
# {'quote': "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”", 'author': 'Marilyn Monroe'}

# %% [markdown]
# **Scraping per Request Directly Into Table for Pandas Analysis Example**

# %%
import requests
import pandas as pd

url = "https://jsonplaceholder.typicode.com/posts"
response = requests.get(url)
data = response.json()

df = pd.DataFrame(data)
print(df.head())

# --- Step 1: Import libraries ---
# requests: to call the API
# pandas: to store and analyze data in a DataFrame
# --- Step 2: Define the API endpoint ---
# JSONPlaceholder is a free fake REST API for testing and prototyping
# --- Step 3: Send GET request ---
# --- Step 4: Convert API response to JSON ---
# .json() turns the response into a Python list of dictionaries
# --- Step 5: Load JSON into a pandas DataFrame ---
# Each dictionary becomes a row, each key becomes a column
# --- Step 6: Preview the first x rows ---
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %% [markdown]
# **Webscraping with For Loop**

# %%
##Web Scraping Example
import requests
from bs4 import BeautifulSoup   # pip install beautifulsoup4

url = "https://www.cnn.com/"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

# Example: get all links
for link in soup.find_all("a"):
    print(link.get("href"))

## --- Web Scraping Example ---
# pip install beautifulsoup4

# --- Step 1: Define the target URL ---
# --- Step 2: Send an HTTP GET request to fetch the page ---
# --- Step 3: Parse the HTML with BeautifulSoup ---
# --- Step 4: Extract all links ---
# Each link is inside an <a> tag
# .find_all("a") finds every anchor element on the page
    # .get("href") extracts the hyperlink (destination URL)

"""
===============================
 SCRAPING DECISION MATRIX
===============================

 What you CAN scrape directly from HTML (requests + BeautifulSoup):
- Static text (headlines, paragraphs, quotes) → <h1>, <p>, <span>
- Links → <a href=...>
- Images → <img src=...>
- Tables → <table>, <tr>, <td>
- Metadata → <title>, <meta>
- Lists of products, quotes, or posts inside <div> blocks

 When HTML ALONE is not enough:
- Dynamic content (loaded with JavaScript) → requests won’t see it
- Infinite scroll feeds (social media, product catalogs) → only loads on scroll
- Interactive forms / login required → HTML just shows login, not data
- Live data (stocks, sports scores) → comes from hidden API calls
- Embedded media (videos, audio streams) → often split into chunks

 Solutions when HTML is not enough:
- Check Network Tab in browser dev tools → often reveals hidden JSON APIs
- If API exists, use requests to hit it directly (cleaner & faster than scraping)
- If no API, simulate browser with Selenium or Playwright to render JS

RULE OF THUMB:
- Start with BeautifulSoup (fast & lightweight).
- If missing data → look for API in Network Tab.
- If still stuck → use Selenium/Playwright as a last resort.
"""
# Out:
# https://www.cnn.com
# https://www.cnn.com/us
# https://www.cnn.com/world
# https://www.cnn.com/politics
# https://www.cnn.com/business
# https://www.cnn.com/health
# https://www.cnn.com/entertainment
# https://www.cnn.com/cnn-underscored
# https://www.cnn.com/style
# https://www.cnn.com/travel
# https://www.cnn.com/sports
# https://www.cnn.com/science
# https://www.cnn.com/climate
# https://www.cnn.com/weather
# https://www.cnn.com/world/europe/ukraine
# https://www.cnn.com/world/middleeast/israel
# https://www.cnn.com/games
# https://www.cnn.com/cnn-underscored/deals/prime-day
# None
# https://www.cnn.com/us
# https://www.cnn.com/world
# https://www.cnn.com/politics
# https://www.cnn.com/business
# https://www.cnn.com/health
# https://www.cnn.com/entertainment
# https://www.cnn.com/cnn-underscored
# https://www.cnn.com/style
# https://www.cnn.com/travel
# https://www.cnn.com/sports
# https://www.cnn.com/science
# https://www.cnn.com/climate
# https://www.cnn.com/weather
# https://www.cnn.com/world/europe/ukraine
# https://www.cnn.com/world/middleeast/israel
# https://www.cnn.com/games
# https://www.cnn.com/cnn-underscored/deals/prime-day
# https://www.cnn.com/video
# https://www.cnn.com/audio
# https://www.cnn.com/live-tv
# /account/settings
# /newsletters
# /follow?iid=fw_var-nav
# #
# #
# /account/settings
# /newsletters
# /follow?iid=fw_var-nav
# #
# #
# https://www.cnn.com/live-tv
# https://www.cnn.com/audio
# https://www.cnn.com/video
# https://us.cnn.com?hpt=header_edition-picker
# https://edition.cnn.com?hpt=header_edition-picker
# https://arabic.cnn.com?hpt=header_edition-picker
# https://cnnespanol.cnn.com/?hpt=header_edition-picker
# https://us.cnn.com?hpt=header_edition-picker
# https://edition.cnn.com?hpt=header_edition-picker
# https://arabic.cnn.com?hpt=header_edition-picker
# https://cnnespanol.cnn.com/?hpt=header_edition-picker
# https://www.cnn.com/us
# https://www.cnn.com/us/crime-and-justice
# https://www.cnn.com/world
# https://www.cnn.com/world/africa
# https://www.cnn.com/world/americas
# https://www.cnn.com/world/asia
# https://www.cnn.com/world/australia
# https://www.cnn.com/world/china
# https://www.cnn.com/world/europe
# https://www.cnn.com/world/india
# https://www.cnn.com/world/middle-east
# https://www.cnn.com/world/united-kingdom
# https://www.cnn.com/politics
# https://www.cnn.com/politics/president-donald-trump-47
# https://www.cnn.com/politics/fact-check
# https://www.cnn.com/polling
# https://www.cnn.com/election/2025
# https://www.cnn.com/business
# https://www.cnn.com/business/tech
# https://www.cnn.com/business/media
# https://www.cnn.com/business/financial-calculators
# https://www.cnn.com/business/videos
# https://www.cnn.com/markets
# https://www.cnn.com/markets/premarkets
# https://www.cnn.com/markets/after-hours
# https://www.cnn.com/markets/fear-and-greed
# https://www.cnn.com/business/investing
# https://www.cnn.com/business/markets-now
# https://www.cnn.com/business/markets/nightcap
# https://www.cnn.com/health
# https://www.cnn.com/interactive/life-but-better/
# https://www.cnn.com/health/life-but-better/fitness
# https://www.cnn.com/health/life-but-better/food
# https://www.cnn.com/health/life-but-better/sleep
# https://www.cnn.com/health/life-but-better/mindfulness
# https://www.cnn.com/health/life-but-better/relationships
# https://www.cnn.com/cnn-underscored
# https://www.cnn.com/cnn-underscored/electronics
# https://www.cnn.com/cnn-underscored/fashion
# https://www.cnn.com/cnn-underscored/beauty
# https://www.cnn.com/cnn-underscored/health-fitness
# https://www.cnn.com/cnn-underscored/home
# https://www.cnn.com/cnn-underscored/reviews
# https://www.cnn.com/cnn-underscored/deals
# https://www.cnn.com/cnn-underscored/gifts
# https://www.cnn.com/cnn-underscored/travel
# https://www.cnn.com/cnn-underscored/outdoors
# https://www.cnn.com/cnn-underscored/pets
# https://www.cnn.com/entertainment
# https://www.cnn.com/entertainment/movies
# https://www.cnn.com/entertainment/tv-shows
# https://www.cnn.com/entertainment/celebrities
# https://www.cnn.com/business/tech
# https://www.cnn.com/business/tech/innovate
# https://www.cnn.com/business/tech/foreseeable-future
# https://www.cnn.com/business/tech/mission-ahead
# https://www.cnn.com/business/work-transformed
# https://www.cnn.com/business/tech/innovative-cities
# https://www.cnn.com/style
# https://www.cnn.com/style/arts
# https://www.cnn.com/style/design
# https://www.cnn.com/style/fashion
# https://www.cnn.com/style/architecture
# https://www.cnn.com/style/luxury
# https://www.cnn.com/style/beauty
# https://www.cnn.com/style/videos
# https://www.cnn.com/travel
# https://www.cnn.com/travel/destinations
# https://www.cnn.com/travel/food-and-drink
# https://www.cnn.com/travel/stay
# https://www.cnn.com/travel/videos
# https://www.cnn.com/sports
# https://bleacherreport.com/nfl
# https://bleacherreport.com/college-football
# https://bleacherreport.com/nba
# https://bleacherreport.com/mlb
# https://bleacherreport.com/world-football
# https://www.cnn.com/sport/paris-olympics-2024
# https://bleacherreport.com/nhl
# https://www.cnn.com/science
# https://www.cnn.com/science/space
# https://www.cnn.com/science/life
# https://www.cnn.com/science/unearthed
# https://www.cnn.com/climate
# https://www.cnn.com/climate/solutions
# https://www.cnn.com/weather
# https://www.cnn.com/weather
# https://www.cnn.com/weather/video
# https://www.cnn.com/climate
# https://www.cnn.com/world/europe/ukraine
# https://www.cnn.com/world/middleeast/israel
# https://www.cnn.com/videos
# https://www.cnn.com/about/live-tv
# https://www.cnn.com/tv/all-shows
# https://www.cnn.com/tv/schedule/cnn
# https://www.cnn.com/videos
# https://www.cnn.com/videos/fast/cnn-headlines
# https://www.cnn.com/shorts/cnn-shorts
# https://www.cnn.com/specials/tv/all-shows
# https://www.cnn.com/cnn10
# https://www.max.com/channel/cnn-max
# https://www.cnn.com/tv/schedule/cnn
# https://www.cnn.com/subscription/video/flashdocs/library
# https://www.cnn.com/audio
# https://www.cnn.com/audio/podcasts/5-things
# https://www.cnn.com/audio/podcasts/chasing-life
# https://www.cnn.com/audio/podcasts/the-assignment
# https://www.cnn.com/audio/podcasts/one-thing
# https://www.cnn.com/audio/podcasts/tug-of-war
# https://www.cnn.com/audio/podcasts/political-briefing
# https://www.cnn.com/audio/podcasts/axe-files
# https://www.cnn.com/audio/podcasts/all-there-is-with-anderson-cooper
# https://www.cnn.com/audio
# https://www.cnn.com/games
# https://www.cnn.com/games/play/cnn-crossword
# https://www.cnn.com/games/play/jumble-crossword-daily
# https://www.cnn.com/games/play/photo-shuffle
# https://www.cnn.com/games/play/sudoblock
# https://www.cnn.com/games/play/daily-sudoku
# https://cnn.it/5thingsquiz
# https://www.cnn.com/cnn-underscored/deals/prime-day
# https://www.cnn.com/about
# https://www.cnn.com/subscription?source=sub_web_footersubnav-link
# https://www.cnn.com/world/photos
# https://www.cnn.com/us/cnn-investigates
# https://www.cnn.com/profiles
# https://www.cnn.com/profiles/cnn-leadership
# https://www.cnn.com/newsletters
# https://careers.wbd.com/cnnjobs
# https://facebook.com/CNN
# https://twitter.com/CNN
# https://instagram.com/CNN
# https://www.tiktok.com/@cnn?lang=en
# https://www.linkedin.com/company/cnn
# /world/live-news/manchester-uk-synagogue-attack-10-02-25
# /politics/live-news/government-shutdown-news-10-02-25
# /2025/10/02/us/trump-national-guard-portland-memphis-wwk-hnk
# /2025/10/02/entertainment/taylor-swift-new-album-eras
# /2025/10/02/sport/baseball-mlb-dodgers-wild-card-intl
# /2025/10/02/entertainment/peaky-blinders-sequel
# https://www.cnn.com/cnn-underscored/gifts/white-elephant-gift-ideas
# /2025/10/02/us/video/delta-regional-jets-collision-digvid
# /2025/10/02/us/video/delta-regional-jets-collision-digvid
# /2025/10/02/politics/trump-admin-us-armed-conflict-cartels
# /2025/10/02/politics/trump-admin-us-armed-conflict-cartels
# /2025/10/02/uk/uk-synagogue-attack-manchester-intl
# /2025/10/02/uk/uk-synagogue-attack-manchester-intl
# /politics/live-news/government-shutdown-news-10-02-25
# /politics/live-news/government-shutdown-news-10-02-25
# /politics/live-news/government-shutdown-news-10-02-25
# /2025/10/02/politics/democrats-government-shutdown-leverage
# /2025/10/02/politics/federal-workers-government-shutdown-emails-partisan
# /2025/10/02/politics/russ-vought-shutdown-architect
# /2025/10/02/politics/russ-vought-shutdown-architect
# /2025/10/02/us/video/government-shutdown-impact-military-families-home-front-digvid
# /2025/10/02/us/video/government-shutdown-impact-military-families-home-front-digvid
# /2025/09/26/politics/government-shutdown-september-2025-explained
# /2025/09/26/politics/government-shutdown-september-2025-explained
# https://www.cnn.com/
# /videos/fast/cnn-headlines
# /2025/10/02/uk/prince-william-interview-eugene-levy-latam-intl
# /2025/10/02/uk/prince-william-interview-eugene-levy-latam-intl
# /2025/10/02/science/rogue-planet-growth-spurt
# /2025/10/02/science/rogue-planet-growth-spurt
# /travel/american-woman-move-spain-30s-helping-others
# /travel/american-woman-move-spain-30s-helping-others
# /2025/10/02/business/video/e-bikes-sales-commute-lbg-wellness-digvid
# /2025/10/02/business/video/e-bikes-sales-commute-lbg-wellness-digvid
# /2025/10/02/politics/kash-patel-fires-fbi-trainee-for-displaying-pride-flag
# /2025/10/02/politics/kash-patel-fires-fbi-trainee-for-displaying-pride-flag
# /2025/10/02/us/5-things-pm-10-2-trnd
# /2025/10/02/politics/video/shadow-docket-trump-supreme-court-explained
# /2025/10/02/media/riyadh-comedy-festival-american-comedians-saudi-human-rights
# /2025/10/02/us/video/killer-whale-washington-southern-resident-endangered-vrtc
# /2025/10/02/europe/putin-russia-act-quickly-western-provocation-latam-intl
# https://bleacherreport.com/articles/25254742-2025-nfl-week-5-expert-picks
# /2025/10/02/us/des-moines-superintendent-ian-roberts-charged
# /2025/10/01/middleeast/israel-gaza-flotilla-explainer-scli-intl
# /2025/10/01/middleeast/israel-gaza-flotilla-explainer-scli-intl
# /2025/10/02/world/video/greta-thunberg-releases-interception-video-ldndigvid-vrtc
# /2025/10/02/business/401k-catchup-contributions-to-be-taxed
# /2025/10/02/business/401k-catchup-contributions-to-be-taxed
# /2025/10/02/business/tariff-halloween-prices
# /cnn-underscored/deals/best-amazon-deals-2025-10-01
# /cnn-underscored/deals/best-amazon-deals-2025-10-01
# /cnn-underscored/reviews/truskin-vitamin-c-serum
# /cnn-underscored/reviews/truskin-vitamin-c-serum
# /cnn-underscored/home/editor-favorite-car-products
# /cnn-underscored/home/editor-favorite-car-products
# /2025/10/02/health/fda-generic-abortion-pill
# /2025/10/02/health/fda-generic-abortion-pill
# /2025/10/02/health/menopause-hrt-warning-change-makary
# /2025/10/02/us/video/heidi-carman-first-responder-therapy-dogs-cnnheroes
# /2025/10/02/entertainment/taylor-swift-new-album-eras
# /2025/10/02/entertainment/taylor-swift-new-album-eras
# /2025/10/02/entertainment/video/tiktok-trend-predicting-taylor-swift-album-viral-vrtc
# /2025/10/02/entertainment/video/tiktok-trend-predicting-taylor-swift-album-viral-vrtc
# /2025/10/02/entertainment/sean-diddy-combs-letter
# /2025/10/02/entertainment/sean-diddy-combs-letter
# /2025/10/02/us/ice-impersonator-incidents-rise-invs-vis
# /2025/10/02/us/ice-impersonator-incidents-rise-invs-vis
# /2025/10/01/business/401k-markets-economy-shutdown
# /2025/10/01/business/401k-markets-economy-shutdown
# /2025/09/30/politics/lindsey-halligan-comey-political-prosecution-kfile
# /2025/09/30/politics/lindsey-halligan-comey-political-prosecution-kfile
# https://www.cnn.com/cnn-underscored
# /cnn-underscored/reviews/snorinator-anti-snoring-pillow
# /cnn-underscored/reviews/snorinator-anti-snoring-pillow
# /cnn-underscored/gifts/diwali-gifts
# /cnn-underscored/reviews/best-headphones-for-sleeping
# /cnn-underscored/beauty/best-leave-in-conditioners
# /cnn-underscored/deals/prana-fall-sale-2025-10-02
# /cnn-underscored/reviews/best-leaf-blower
# /cnn-underscored/reviews/best-leaf-blower
# /cnn-underscored/reviews/best-drip-coffee-makers
# /cnn-underscored/reviews/best-water-flossers
# /cnn-underscored/reviews/best-kitchen-knife-sets
# /cnn-underscored/gifts/unique-gift-ideas
# /cnn-underscored/deals/early-amazon-prime-day-tv-deals-2025-10-02
# /cnn-underscored/deals/early-amazon-prime-day-tv-deals-2025-10-02
# /cnn-underscored/fashion/best-barn-jackets
# /cnn-underscored/reviews/best-kitchen-trash-can
# /cnn-underscored/gifts/white-elephant-gift-ideas
# /cnn-underscored/money/prime-visa-credit-card
# /2025/10/02/travel/video/eugene-levy-prince-william-windsor-castle-reluctant-traveler-vrtc
# /2025/10/02/travel/video/eugene-levy-prince-william-windsor-castle-reluctant-traveler-vrtc
# /2025/10/02/world/video/russian-drones-planes-nato-vrtc
# /2025/10/02/world/video/russian-drones-planes-nato-vrtc
# /2025/10/02/health/video/matcha-iron-deficiency-vrtc
# /2025/10/02/health/video/matcha-iron-deficiency-vrtc
# /2025/10/02/world/video/pope-leo-us-immigration-policies-inhuman-digvid-vrtc
# /2025/10/02/world/video/pope-leo-us-immigration-policies-inhuman-digvid-vrtc
# /2025/10/01/politics/video/trump-hegseth-messaging-military-leaders-ebof-vrtc
# /2025/10/01/politics/video/trump-hegseth-messaging-military-leaders-ebof-vrtc
# /2025/10/02/world/video/yasmin-nasir-recipes-gaza-vrtc
# /2025/10/02/world/video/yasmin-nasir-recipes-gaza-vrtc
# /2025/10/02/sport/video/afghan-womens-refugee-team-uk-digvid-vrtc
# /2025/10/02/sport/video/afghan-womens-refugee-team-uk-digvid-vrtc
# /2025/10/01/politics/video/jane-fonda-trump-presidency-frightening-vrtc
# /2025/10/01/politics/video/jane-fonda-trump-presidency-frightening-vrtc
# /2025/10/01/us/video/jane-goodall-obit-vrtc
# /2025/10/01/us/video/jane-goodall-obit-vrtc
# /2025/10/01/travel/video/tsa-agents-government-shutdown-vrtc
# /2025/10/01/travel/video/tsa-agents-government-shutdown-vrtc
# /2025/10/01/entertainment/video/colbert-joins-kimmel-late-night-interview-vrtc
# /2025/10/01/entertainment/video/colbert-joins-kimmel-late-night-interview-vrtc
# /2025/10/01/world/video/music-missile-belgorod-russia-ukraine-vrtc
# /2025/10/01/world/video/music-missile-belgorod-russia-ukraine-vrtc
# /2025/10/02/us/arizona-amazon-drones-crash
# /2025/10/02/us/arizona-amazon-drones-crash
# /2025/10/02/business/tesla-sales-third-quarter-ev-rebate
# /2025/10/02/business/tesla-sales-third-quarter-ev-rebate
# /2025/10/01/business/video/ai-heart-health-cardiologist-digvid
# /2025/10/01/business/video/ai-heart-health-cardiologist-digvid
# /2025/10/02/style/pamela-anderson-red-hair-paris-fashion-week
# /2025/10/02/style/pamela-anderson-red-hair-paris-fashion-week
# /2025/10/01/style/chinatowns-morris-lum-photos
# /2025/10/01/style/chinatowns-morris-lum-photos
# /2025/10/02/style/video/takashi-murakami-studio-superflat-style-spc-digvid
# /2025/10/02/style/video/takashi-murakami-studio-superflat-style-spc-digvid
# /2025/09/30/weather/hurricane-forecast-imelda-strengthens-flooding-climate-hnk
# /2025/09/30/weather/hurricane-forecast-imelda-strengthens-flooding-climate-hnk
# /2025/09/30/us/video/outerbanks-north-carolina-5-house-collapse-vrtc
# /2025/09/30/us/video/outerbanks-north-carolina-5-house-collapse-vrtc
# /2025/09/30/climate/coal-power-trump-public-lands
# /2025/09/30/climate/coal-power-trump-public-lands
# /2025/10/02/sport/olympics-caster-semenya-ends-sex-eligibility-legal-fight
# /2025/10/02/sport/olympics-caster-semenya-ends-sex-eligibility-legal-fight
# /2025/10/02/sport/football-nfl-week-5-five-things
# /2025/10/02/sport/basketball-wnba-caitlin-clark-napheesa-collier-sophie-cunningham
# /2025/10/02/sport/golf-ryder-cup-hatton-fans-intl
# https://bleacherreport.com/?utm_source=cnn.com&utm_medium=referral&utm_campaign=editorial
# https://bleacherreport.com/articles/25255389-angel-reese-says-she-made-6-figures-plus-mebounds-merch-tried-clown-me?utm_source=cnn.com&utm_medium=referral&utm_campaign=editorial
# https://bleacherreport.com/articles/25255389-angel-reese-says-she-made-6-figures-plus-mebounds-merch-tried-clown-me?utm_source=cnn.com&utm_medium=referral&utm_campaign=editorial
# https://bleacherreport.com/articles/25255299-sophie-cunningham-starts-joke-gofundme-fines-after-criticizing-wnba-commish?utm_source=cnn.com&utm_medium=referral&utm_campaign=editorial
# https://bleacherreport.com/articles/25255180-shedeur-sanders-keeps-making-his-biggest-problem-worse?utm_source=cnn.com&utm_medium=referral&utm_campaign=editorial
# https://bleacherreport.com/articles/25255248-dolphins-tua-tagovailoa-talks-diet-changes-help-avoid-future-concussions-video?utm_source=cnn.com&utm_medium=referral&utm_campaign=editorial
# https://bleacherreport.com/articles/25254854-speed-trains-tom-brady-sauce-gardner-amendola-be-nfl-player-new-video?utm_source=cnn.com&utm_medium=referral&utm_campaign=editorial
# /2025/10/02/us/robert-morris-texas-megachurch-guilty-plea
# /2025/10/02/us/robert-morris-texas-megachurch-guilty-plea
# /2025/10/01/us/bronx-nyc-partial-building-collapse
# /2025/10/01/us/bronx-nyc-partial-building-collapse
# /2025/09/30/us/ice-new-york-immigration-court-jounalists
# /2025/09/30/us/ice-new-york-immigration-court-jounalists
# /2025/10/02/politics/senate-gop-georgia-fundraiser-democrats-napa-shutdown
# /2025/10/02/politics/senate-gop-georgia-fundraiser-democrats-napa-shutdown
# /2025/10/02/us/trump-national-guard-portland-memphis-wwk-hnk
# /2025/10/02/us/trump-national-guard-portland-memphis-wwk-hnk
# /2025/10/01/politics/supreme-court-agrees-to-hear-arguments-in-case-on-federal-reserve-independence
# /2025/10/01/politics/supreme-court-agrees-to-hear-arguments-in-case-on-federal-reserve-independence
# /2025/10/02/europe/nato-surveillance-flight-eastern-sentry-intl
# /2025/10/02/europe/nato-surveillance-flight-eastern-sentry-intl
# /2025/10/01/europe/jane-goodall-death-latam-intl
# /2025/10/01/europe/jane-goodall-death-latam-intl
# /2025/10/02/asia/indonesia-school-collapse-rescues-families-intl-hnk
# /2025/10/02/asia/indonesia-school-collapse-rescues-families-intl-hnk
# /2025/10/02/us/bryan-kohberger-case-judge-bars-photos-hnk
# /2025/10/02/us/bryan-kohberger-case-judge-bars-photos-hnk
# /2025/10/01/entertainment/tyrese-gibson-dog-attack
# /2025/10/01/entertainment/tyrese-gibson-dog-attack
# /2025/10/01/us/michigan-church-shooting-victim-daughter-letter
# /2025/10/01/us/michigan-church-shooting-victim-daughter-letter
# /2025/09/30/us/what-we-know-michigan-church-shooting
# /2025/09/30/us/what-we-know-michigan-church-shooting
# /2025/09/30/us/nurses-strike-michigan-shooting-fire
# /2025/09/30/us/nurses-strike-michigan-shooting-fire
# /2025/09/30/us/video/michigan-church-shooter-mormons-antichrist-vrtc
# /2025/09/30/us/video/michigan-church-shooter-mormons-antichrist-vrtc
# /2025/10/02/travel/video/nyc-food-truck-tony-shalhoub-ten-bucks-digvid
# /2025/10/02/travel/video/nyc-food-truck-tony-shalhoub-ten-bucks-digvid
# /travel/last-minute-flight-romance-chance-encounters
# /travel/last-minute-flight-romance-chance-encounters
# /travel/hamam-turkish-bath-istanbul-what-happens
# /travel/hamam-turkish-bath-istanbul-what-happens
# /2025/10/01/asia/japan-warship-tomahawk-missiles-intl-hnk-ml
# /2025/10/01/asia/japan-warship-tomahawk-missiles-intl-hnk-ml
# /2025/09/30/travel/video/western-influencer-kenqing-technology-robotic-exoskeletons-digvid
# /2025/09/30/travel/video/western-influencer-kenqing-technology-robotic-exoskeletons-digvid
# /travel/robotic-exoskeleton-hiking-china-intl-hnk
# /travel/robotic-exoskeleton-hiking-china-intl-hnk
# /2025/10/01/tech/peloton-relaunch-ai-new-equipment
# /2025/10/01/tech/peloton-relaunch-ai-new-equipment
# /2025/09/29/business/video/ancestra-eliza-mcnitt-generative-ai-film-spc-digvid
# /2025/09/29/business/video/ancestra-eliza-mcnitt-generative-ai-film-spc-digvid
# /2025/09/23/tech/google-study-90-percent-tech-jobs-ai
# /2025/09/23/tech/google-study-90-percent-tech-jobs-ai
# https://www.cnn.com/games/play/sudoblock?utm_source=games_acq_web_homepage_morezone
# https://www.cnn.com/games/play/sudoblock?utm_source=games_acq_web_homepage_morezone
# https://www.cnn.com/games/play/daily-crossword?utm_source=games_acq_web_homepage_morezone
# https://www.cnn.com/games/play/daily-crossword?utm_source=games_acq_web_homepage_morezone
# https://www.cnn.com/games/play/jumble-crossword-daily
# https://www.cnn.com/games/play/jumble-crossword-daily
# https://cnn.it/5thingsquiz?utm_source=games_acq_web_homepage_morezone
# https://cnn.it/5thingsquiz?utm_source=games_acq_web_homepage_morezone
# /2025/09/30/politics/lindsey-halligan-trump-attorney-comey-indictment
# /2025/09/30/politics/lindsey-halligan-trump-attorney-comey-indictment
# /2025/09/28/politics/chicago-police-violence-torture-podcast-omar-jimenez
# /2025/10/01/us/remembering-jane-goodall-through-her-favorite-charities
# /2025/10/01/business/nike-earnings-tariff-china
# /2025/10/01/africa/dr-congo-kabila-death-sentence-intl
# /2025/09/30/asia/nepal-girl-new-living-goddess-intl-hnk
# /2025/09/29/style/milan-fashion-week-spring-summer-2026-highlights
# /2025/09/30/tech/scale-ai-making-money-meta
# /2025/09/28/style/bottega-veneta-spring-summer-2026-debut-louise-trotter
# /account/settings
# /newsletters
# /follow?iid=fw_var-nav
# #
# #
# https://www.cnn.com/live-tv
# https://www.cnn.com/audio
# https://www.cnn.com/video
# https://www.cnn.com/us
# https://www.cnn.com/us/crime-and-justice
# https://www.cnn.com/world
# https://www.cnn.com/world/africa
# https://www.cnn.com/world/americas
# https://www.cnn.com/world/asia
# https://www.cnn.com/world/australia
# https://www.cnn.com/world/china
# https://www.cnn.com/world/europe
# https://www.cnn.com/world/india
# https://www.cnn.com/world/middle-east
# https://www.cnn.com/world/united-kingdom
# https://www.cnn.com/politics
# https://www.cnn.com/politics/president-donald-trump-47
# https://www.cnn.com/politics/fact-check
# https://www.cnn.com/polling
# https://www.cnn.com/election/2025
# https://www.cnn.com/business
# https://www.cnn.com/business/tech
# https://www.cnn.com/business/media
# https://www.cnn.com/business/financial-calculators
# https://www.cnn.com/business/videos
# https://www.cnn.com/markets
# https://www.cnn.com/markets/premarkets
# https://www.cnn.com/markets/after-hours
# https://www.cnn.com/markets/fear-and-greed
# https://www.cnn.com/business/investing
# https://www.cnn.com/business/markets-now
# https://www.cnn.com/business/markets/nightcap
# https://www.cnn.com/health
# https://www.cnn.com/interactive/life-but-better/
# https://www.cnn.com/health/life-but-better/fitness
# https://www.cnn.com/health/life-but-better/food
# https://www.cnn.com/health/life-but-better/sleep
# https://www.cnn.com/health/life-but-better/mindfulness
# https://www.cnn.com/health/life-but-better/relationships
# https://www.cnn.com/cnn-underscored
# https://www.cnn.com/cnn-underscored/electronics
# https://www.cnn.com/cnn-underscored/fashion
# https://www.cnn.com/cnn-underscored/beauty
# https://www.cnn.com/cnn-underscored/health-fitness
# https://www.cnn.com/cnn-underscored/home
# https://www.cnn.com/cnn-underscored/reviews
# https://www.cnn.com/cnn-underscored/deals
# https://www.cnn.com/cnn-underscored/gifts
# https://www.cnn.com/cnn-underscored/travel
# https://www.cnn.com/cnn-underscored/outdoors
# https://www.cnn.com/cnn-underscored/pets
# https://www.cnn.com/entertainment
# https://www.cnn.com/entertainment/movies
# https://www.cnn.com/entertainment/tv-shows
# https://www.cnn.com/entertainment/celebrities
# https://www.cnn.com/business/tech
# https://www.cnn.com/business/tech/innovate
# https://www.cnn.com/business/tech/foreseeable-future
# https://www.cnn.com/business/tech/mission-ahead
# https://www.cnn.com/business/work-transformed
# https://www.cnn.com/business/tech/innovative-cities
# https://www.cnn.com/style
# https://www.cnn.com/style/arts
# https://www.cnn.com/style/design
# https://www.cnn.com/style/fashion
# https://www.cnn.com/style/architecture
# https://www.cnn.com/style/luxury
# https://www.cnn.com/style/beauty
# https://www.cnn.com/style/videos
# https://www.cnn.com/travel
# https://www.cnn.com/travel/destinations
# https://www.cnn.com/travel/food-and-drink
# https://www.cnn.com/travel/stay
# https://www.cnn.com/travel/news
# https://www.cnn.com/travel/videos
# https://www.cnn.com/sports
# https://bleacherreport.com/nfl
# https://bleacherreport.com/college-football
# https://bleacherreport.com/nba
# https://bleacherreport.com/mlb
# https://bleacherreport.com/world-football
# https://www.cnn.com/sport/paris-olympics-2024
# https://bleacherreport.com/nhl
# https://www.cnn.com/science
# https://www.cnn.com/science/space
# https://www.cnn.com/science/life
# https://www.cnn.com/science/unearthed
# https://www.cnn.com/climate
# https://www.cnn.com/climate/solutions
# https://www.cnn.com/weather
# https://www.cnn.com/weather
# https://www.cnn.com/weather/video
# https://www.cnn.com/climate
# https://www.cnn.com/world/europe/ukraine
# https://www.cnn.com/world/middleeast/israel
# https://www.cnn.com/watch
# https://www.cnn.com/watch
# https://www.cnn.com/watch#shows-and-films
# https://www.cnn.com/videos/live
# https://www.cnn.com/videos
# https://www.cnn.com/videos/fast/cnn-headlines
# https://www.cnn.com/shorts/cnn-shorts
# https://www.cnn.com/tv/all-shows
# https://www.cnn.com/cnn10
# https://www.max.com/channel/cnn-max
# https://www.cnn.com/tv/schedule/cnn
# https://www.cnn.com/subscription/video/flashdocs/library
# https://www.cnn.com/audio
# https://www.cnn.com/audio/podcasts/5-things
# https://www.cnn.com/audio/podcasts/chasing-life
# https://www.cnn.com/audio/podcasts/the-assignment
# https://www.cnn.com/audio/podcasts/one-thing
# https://www.cnn.com/audio/podcasts/tug-of-war
# https://www.cnn.com/audio/podcasts/political-briefing
# https://www.cnn.com/audio/podcasts/axe-files
# https://www.cnn.com/audio/podcasts/all-there-is-with-anderson-cooper
# https://www.cnn.com/audio
# https://www.cnn.com/games
# https://www.cnn.com/games/play/cnn-crossword
# https://www.cnn.com/games/play/jumble-crossword-daily
# https://www.cnn.com/games/play/photo-shuffle
# https://www.cnn.com/games/play/sudoblock
# https://www.cnn.com/games/play/daily-sudoku
# https://cnn.it/5thingsquiz
# https://www.cnn.com/cnn-underscored/deals/prime-day
# https://www.cnn.com/about
# https://www.cnn.com/subscription?source=sub_web_footersubnav-link
# https://www.cnn.com/world/photos
# https://www.cnn.com/us/cnn-investigates
# https://www.cnn.com/profiles
# https://www.cnn.com/profiles/cnn-leadership
# https://www.cnn.com/newsletters
# https://careers.wbd.com/cnnjobs
# https://www.cnn.com
# https://www.cnn.com/video
# https://www.cnn.com/audio
# https://www.cnn.com/live-tv
# https://facebook.com/CNN
# https://twitter.com/CNN
# https://instagram.com/CNN
# https://www.tiktok.com/@cnn?lang=en
# https://www.linkedin.com/company/cnn
# /account/settings
# /newsletters
# /follow?iid=fw_var-nav
# #
# #
# https://www.cnn.com/terms
# https://www.cnn.com/privacy
# #
# https://www.cnn.com/ad-choices
# https://www.cnn.com/accessibility
# https://www.cnn.com/about
# https://www.cnn.com/subscription?source=sub_web_footerlink-link
# https://www.cnn.com/newsletters
# https://www.cnn.com/transcripts
# https://help.cnn.com/

# %% [markdown]
# ## **CRON Automated Job Scheduling**

# %% [markdown]
# **STEPS & WORKFLOW EXAMPLE**

# %% [markdown]
# **1. The crontab schedule format**

# %%
0 6 * * * /usr/bin/python3 /home/kev/scripts/etl_pipeline.py 

## → Run every day at 6:00 AM.
# Out:
#   Cell In[29], line 1
#     0 6 * * * /usr/bin/python3 /home/kev/scripts/etl_pipeline.py
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# **2. A Python ETL script (etl_pipeline.py)**

# %%
import requests, pandas as pd
url = "https://jsonplaceholder.typicode.com/users" 
data = requests.get(url).json()
df = pd.DataFrame(data)[["id", "name", "email"]]
df.to_csv("/home/kev/data/users.csv", index=False)

## → Pulls API data, transforms with pandas, saves to CSV.

# %% [markdown]
# **3. How to register it with CRON**

# %%
crontab -e
0 6 * * * /usr/bin/python3 /home/kev/scripts/etl_pipeline.py >> /home/kev/logs/etl.log 2>&1

## → Makes it run automatically at 6AM, logs output.
